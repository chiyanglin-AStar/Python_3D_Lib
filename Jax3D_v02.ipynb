# %% [markdown]
# <a href="https://colab.research.google.com/github/chiyanglin-AStar/Python_3D_Lib/blob/main/Jax3D_v02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 要做Jax3D 在Colab 的tutorial ,也要有安裝步驟 其中的範例 要能表現 Jax3D 的 特性 , 要加上程式說明, 請先提出這tutorial 綱要跟計畫, 也把對話紀錄記錄在筆記本裡 輸出用 Markdown 繁體中文
# 好的，我已經為您規劃了一個詳細的 Jax3D Colab 教學大綱。這個教學將包含安裝步驟、Jax3D 特性範例、程式碼說明，並會以繁體中文的 Markdown 格式呈現。請審閱這個計畫，並讓我知道您是否有任何調整。
#
# 安裝 Jax3D 及其依賴: 在 Colab 環境中安裝 Jax3D 及其所有必要的依賴套件，確保環境準備就緒。
# 導入 Jax3D 函式庫: 導入 Jax3D 及其相關的函式庫，以便在 Colab 中使用它們的功能。
# 展示 Jax3D 特性範例 - JIT 編譯: 設計一個 Jax3D 範例，特別展示其即時編譯 (JIT) 的特性，並解釋 JIT 如何提高性能。
# 展示 Jax3D 特性範例 - Vmap 自動向量化: 設計一個 Jax3D 範例，展示其自動向量化 (Vmap) 的能力，並說明它如何簡化程式碼並提升效率。
# 展示 Jax3D 特性範例 - Grad 自動微分: 設計一個 Jax3D 範例，展示其自動微分 (Grad) 的功能，並解釋這對於機器學習和優化任務的重要性。
# 程式碼說明與特性解釋: 為每個範例提供詳細的程式碼說明，並闡釋 Jax3D 各項特性（JIT、Vmap、Grad）背後的原理和優勢。
# 最終任務: 總結 Jax3D 的主要特性及其在 Colab 中使用的優勢，並提供進一步學習的建議。

# %% [markdown]
# # Task
# Install Jax3D and its dependencies in Colab, then demonstrate its JIT, Vmap, and Grad features through code examples, explain their benefits, and summarize Jax3D's advantages in Colab.

# %% [markdown]
# ## 安裝 Jax3D 及其依賴
#
# ### Subtask:
# 在 Colab 環境中安裝 Jax3D 及其所有必要的依賴套件，確保環境準備就緒。

# %% [markdown]
# **Reasoning**:
# First, I need to install the specified versions of JAX and JAXlib using pip. This is a prerequisite for Jax3D.

# %%
import warnings
warnings.filterwarnings('ignore')

# Uninstall conflicting packages that depend on newer JAX versions
# !pip uninstall -y flax orbax-checkpoint optax

# Install the specified versions of JAX and JAXlib
# !pip install jax==0.4.23 jaxlib==0.4.23 --no-warn-script-location
# Out:
# Found existing installation: flax 0.11.2
# Uninstalling flax-0.11.2:
#   Successfully uninstalled flax-0.11.2
# Found existing installation: orbax-checkpoint 0.11.33
# Uninstalling orbax-checkpoint-0.11.33:
#   Successfully uninstalled orbax-checkpoint-0.11.33
# Found existing installation: optax 0.2.8
# Uninstalling optax-0.2.8:
#   Successfully uninstalled optax-0.2.8
# ...

# %% [markdown]
# **Reasoning**:
# Now that JAX and JAXlib are correctly installed (or confirmed to be satisfied with the specified versions), the next step is to install Jax3D from its GitHub repository as per the subtask instructions. This completes the installation of all necessary dependencies for Jax3D.

# %%
import warnings
warnings.filterwarnings('ignore')

# Install Jax3D
# !pip install git+https://github.com/google-research/jax3d.git

# Force reinstall JAX and JAXlib to the specified versions (0.4.23)
# to ensure compatibility and adhere to requirements, overriding any upgrades
# !pip install jax==0.4.23 jaxlib==0.4.23 --force-reinstall --no-warn-script-location
# Out:
# ...
#   Cloning https://github.com/google-research/jax3d.git to /tmp/pip-req-build-ivp4_o6c
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/jax3d.git /tmp/pip-req-build-ivp4_o6c
#   Resolved https://github.com/google-research/jax3d.git to commit 7d7122d9edeb59e0fa4ab2e7c4025dd55c17ce04
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/google-research/sunds to /tmp/pip-install-sby8wvhp/sunds_f4e749b64d5641e084df380b06782864
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/sunds /tmp/pip-install-sby8wvhp/sunds_f4e749b64d5641e084df380b06782864
#   Resolved https://github.com/google-research/sunds to commit 089d9243322dff217251dc7ad2d5b589df221853
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
